# %%
import matplotlib.pyplot as plt


fig = plt.figure()
gs = fig.add_gridspec(3, hspace=0)
axs = gs.subplots(sharex=True, sharey=True)
fig.suptitle('Sharing both axes')
axs[0].plot(x, y ** 2)
axs[1].plot(x, 0.3 * y, 'o')
axs[2].plot(x, y, '+')

# Hide x labels and tick labels for all but bottom plot.
for ax in axs:
    ax.label_outer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eito/Github/Useful-Commands/matplotlib.ipynb Cell 1' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/home/eito/Github/Useful-Commands/matplotlib.ipynb#ch0000000?line=5'>6</a> axs = gs.subplots(sharex=True, sharey=True)
#       <a href='vscode-notebook-cell:/home/eito/Github/Useful-Commands/matplotlib.ipynb#ch0000000?line=6'>7</a> fig.suptitle('Sharing both axes')
# ----> <a href='vscode-notebook-cell:/home/eito/Github/Useful-Commands/matplotlib.ipynb#ch0000000?line=7'>8</a> axs[0].plot(x, y ** 2)
#       <a href='vscode-notebook-cell:/home/eito/Github/Useful-Commands/matplotlib.ipynb#ch0000000?line=8'>9</a> axs[1].plot(x, 0.3 * y, 'o')
#      <a href='vscode-notebook-cell:/home/eito/Github/Useful-Commands/matplotlib.ipynb#ch0000000?line=9'>10</a> axs[2].plot(x, y, '+')
#
# NameError: name 'x' is not defined
